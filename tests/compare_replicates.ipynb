# %%
import os, json, sys
sys.path.append(os.path.abspath(os.path.join('..')))
import pandas as pd

from seismic_graph import Study

# %%
data = []

paths = [
    # "/Users/casper/Documents/data/Adam/Astrophage/Astrophage_Data_P3/out/long-rep1__webapp.json",
    # "/Users/casper/Documents/data/Adam/Astrophage/Astrophage_Data_P3/out/long-rep2__webapp.json",
    # "/Users/casper/Documents/data/Adam/Astrophage/Astrophage_Data_P3/out/short-rep1__webapp.json",
    # "/Users/casper/Documents/data/Adam/Astrophage/Astrophage_Data_P3/out/short-rep2__webapp.json",
    # "/Users/casper/Documents/data/Adam/Astrophage/Astrophage_Data_P3/out/all-rep1__webapp.json",
    # "/Users/casper/Documents/data/Adam/Astrophage/Astrophage_Data_P3/out/all-rep2__webapp.json",
    "/Users/casper/Documents/data/Adam/Astrophage/Astrophage_mapQ_20/unpooled/all_rep1__webapp.json",
    "/Users/casper/Documents/data/Adam/Astrophage/Astrophage_mapQ_20/unpooled/all_rep2__webapp.json"
]


for path in paths:
    with open (path, 'r') as file:
        json_data = json.load(file) 
        data.append(json_data)

study = Study(data=data)
# sample, reference, section = study.df.iloc[0][['sample', 'reference', 'section']]
df = study.df
# column_headers = study.df.columns.tolist()
# print(column_headers)

# %%
output = study.pearson_correlation_histogram()
fig = output['fig']
fig.show()

# %%
# Assuming your figure is stored in 'fig'
fig.write_image("/Users/casper/Downloads/correlation_between_replicates.png", format="png", scale=2, width=1920, height=1080)

# %%
csv_string = output["scores_csv"]

# %%
path = "/Users/casper/Documents/output/pearson_correlations_Q20_reps.csv"
# path = "/Users/casper/Documents/output/pearson_correlations_short_reps.csv"
with open(path, "w") as file:
    file.write(csv_string)
